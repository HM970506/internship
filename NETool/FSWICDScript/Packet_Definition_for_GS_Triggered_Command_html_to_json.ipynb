# %%
from bs4 import BeautifulSoup
import pandas as pd
import json
from collections import OrderedDict
from html_table_parser import parser_functions as parser

# %%
##Task id html
html_GSTriggered=open("C:/Users/user/Desktop/FSWICD/TaskID/[ESGS] TMTC Definitions of Between S_C and MCS - SX FSW - Wiki SI.html", 'r', encoding='UTF8')
soup=BeautifulSoup(html_GSTriggered, 'html.parser')

tr=soup.find_all("tr")

td_list=[]
th_list=[]

for now in tr:
    th_find=now.find_all("th")
    td_find=now.find_all("td")
    if(th_find):
        th_now_list=[]
        for th in th_find:
            th_now_list.append(th.get_text())
        th_list.append(th_now_list)
    if(td_find):
        td_now_list=[]
        for td in td_find:
            td_now_list.append(td.get_text().replace(u'\xa0', ''))
        td_list.append(td_now_list)
        
td_list
# Out:
# [['AOCS ADS Set',
#   '0x32',
#   'ELT',
#   'Set ADS of AOCS modules.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['AOCS Power Set',
#   '0x33',
#   'ELT',
#   'Control power of AOCS module immediately, regardless of ADS.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Bootloader High FOS Run',
#   '0x00',
#   'SYS',
#   'Run FOS in Bootloader High.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Cancel File List',
#   '0x34',
#   'ELT',
#   'Cancel file list query sequence.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Cancel File Segment Download',
#   '0x35',
#   'ELT',
#   'Cancel file download sequence.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Cancel File Upload',
#   '0x36',
#   'ELT',
#   'Cancel file upload sequence.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['CAN Bypass',
#   '0x20',
#   'ILT',
#   'Send CAN message generated by GS to a subsystem.',
#   'Pending',
#   'Single',
#   'Pending Info Request'],
#  ['CAN Link Test',
#   '0x21',
#   'ILT',
#   'Run CAN subsystem link test and give the result.',
#   'Pending',
#   'Single',
#   'Pending Info Request'],
#  ['CAN Link Test Cancel',
#   '0x22',
#   'ILT',
#   'Cancel ongoing CAN subsystem link test.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['CAN Node ADS Set',
#   '0x37',
#   'ELT',
#   'Set ADS of CAN subsystem.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['CAN Node Power Set',
#   '0x38',
#   'ELT',
#   'Control power of AOCS module immediately, regardless of ADS.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['CAN Node Simulation Set',
#   '0x39',
#   'ELT',
#   'Ground test purpose only. Let OBC communicate to the simulation node, not an actual subsystem.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['CCSDS Link Test',
#   '0x3A',
#   'ELT',
#   'Run CCSDS link test between SC and GS.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['CCSDS Link Test Reset',
#   '0x3B',
#   'ELT',
#   'Reset CCSDS link test result.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Clear Upload Buffer',
#   '0x3C',
#   'ELT',
#   'Clear upload buffer for the segment.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Default GS Configuration Set',
#   '0x70',
#   'HKT',
#   'Enable or disable setting for G/S use',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['EPS Configuration Set',
#   '0x71',
#   'HKT',
#   'Configuration settings to control EPS',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['File Delete',
#   '0x3D',
#   'ELT',
#   'Delete file from the file system.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Request File List',
#   '0x3E',
#   'ELT',
#   'Start file list query sequence.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['File Segment Download Finish',
#   '0x3F',
#   'ELT',
#   'Finish file download sequence.',
#   'N/A',
#   'Single',
#   'Auto TM'],
#  ['File System Reset',
#   '0x10',
#   'OST',
#   'Format File system specified of FSW',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Finish File List',
#   '0x40',
#   'ELT',
#   'Finish file list query sequence.',
#   'N/A',
#   'Single',
#   'Auto TM'],
#  ['Finish File Upload',
#   '0x41',
#   'ELT',
#   'Finish file upload sequence.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Finish Image File List',
#   '0x80',
#   'PLT',
#   'Notify that the image file list transfer is complete.',
#   'N/A',
#   'Single',
#   'Auto TM'],
#  ['FOS Store',
#   '0x11',
#   'OST',
#   'Store FOS binary file into non-volatile storage',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['GS Total Information',
#   '0x72',
#   'HKT',
#   'Get Default G/S configuration',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['HKT Configuration Save',
#   '0x73',
#   'HKT',
#   'Save all HKT configurations to a file',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['HKT Configuration File Load',
#   '0x7C',
#   'HKT',
#   'Load HKT initial configuration file',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Image File Auto Delete Set',
#   '0x81',
#   'PLT',
#   'Set an auto-delete flag of imaging data or imaging scenario',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Request Image File List',
#   '0x82',
#   'PLT',
#   'Get image file information.',
#   'Immediate',
#   'Single',
#   'InfoRequest'],
#  ['Immediate Tasking Scenario Register',
#   '0x61',
#   'OMT',
#   'Delete all existing scenarios on-board, and load scenario from immediate scenario file.',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Log File Restart',
#   '0x43',
#   'OST',
#   'Close current log files and create new log files.',
#   'Pending',
#   'Single',
#   'Pending Info Request'],
#  ['MISC ADS Set',
#   '0x44',
#   'ELT',
#   'Set ADS of miscellaneous modules.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Network ADS Set',
#   '0x45',
#   'ELT',
#   'Set ADS of CAN bus.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Network Use Status Set',
#   '0x46',
#   'ELT',
#   'Set use which CAN bus. (P or R)',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Request OBT',
#   '0x47',
#   'ELT',
#   'Request current on-board time.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['Set OBT',
#   '0x48',
#   'ELT',
#   'Update current on-board time.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Operation Mode Set',
#   '0x62',
#   'OMT',
#   'Change operation mode of FSW immediately.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Query File Upload Bitmap',
#   '0x49',
#   'ELT',
#   'Request File Upload bitmap data.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['Request File Checksum',
#   '0x4A',
#   'OST',
#   'Calculate CRC32 checksum of a file in the file system.',
#   'Pending',
#   'Single',
#   'Pending Info Request'],
#  ['Request File Write',
#   '0x4B',
#   'ELT',
#   'Request to write segment data to a file.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Request Segment Download',
#   '0x4C',
#   'ELT',
#   'Request download a specific file.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Diagnostic Message',
#   '0x31',
#   'ELT',
#   'Enable or Disable Diagnostic message',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Scenario Cancel',
#   '0x63',
#   'OMT',
#   'Cancel ongoing scenario.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Request Scenario Count',
#   '0x64',
#   'OMT',
#   'Get a number of scenarios in FSW.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['Scenario Delete',
#   '0x65',
#   'OMT',
#   'Delete planned scenario.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Request Scenario ID List',
#   '0x66',
#   'OMT',
#   'Get the list of scenarios in FSW.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['Scenario Query',
#   '0x67',
#   'OMT',
#   'Check a specific scenario is registered or not in FSW.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Scenario Register',
#   '0x68',
#   'OMT',
#   'Load and register scenarios from the scenario file.',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Scenario Save',
#   '0x69',
#   'OMT',
#   'Save scenarios in FSW to a file in the file system.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['SSRU File System Format',
#   '0x6A',
#   'OMT',
#   'Format SSRU file system.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Subsystem Parameter Update',
#   '0x6B',
#   'OMT',
#   'Transfer parameter file to a subsystem.',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Parameter Update Cancel',
#   '0x6C',
#   'OMT',
#   'Cancel subsystem parameter update sequence.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['SSRU File System Format Cancel',
#   '0x6D',
#   'OMT',
#   'Cancel SSRU File system format sequence.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Force House Keeping Set',
#   '0x6E',
#   'OMT',
#   'Set OMT housekeeping mode',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['SSRU File List Get',
#   '0x84',
#   'PLT',
#   'Get image file information.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Stored FSW Information',
#   '0x12',
#   'OST',
#   'Get information of tasks stored in non-volatile storage.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['STx Control Mode Set',
#   '0x74',
#   'HKT',
#   'Configuration settings to control S-band transmission',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['SW Version List',
#   '0x13',
#   'OST',
#   'Request all FSW version information',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['Task Delete',
#   '0x14',
#   'OST',
#   'Delete a task from non-volatile storage.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Task Exit',
#   '0x15',
#   'OST',
#   'Stop execution of the task.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Task Ram Run',
#   '0x16',
#   'OST',
#   'Start execution of task stored in the file system.',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Task Rom Run',
#   '0x17',
#   'OST',
#   'Start execution of task stored in non-volatile storage.',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Task Store',
#   '0x18',
#   'OST',
#   'Store task binary file into non-volatile storage',
#   'Pending',
#   'Single',
#   'Pending Command'],
#  ['Temporary GS Add',
#   '0x75',
#   'HKT',
#   'Add temporary G/S position',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Temporary GS Delete',
#   '0x76',
#   'HKT',
#   'Delete temporary G/S position',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Thermal Configuration Set',
#   '0x77',
#   'HKT',
#   'Configuration settings to control Thermal',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['TIB Period Set',
#   '0x4E',
#   'ELT',
#   'Set TIB transmission frequency.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Transfer File List',
#   '0x4F',
#   'ELT',
#   'File information stored in the file system.',
#   'N/A',
#   'Multi',
#   'Auto TM'],
#  ['Transfer File Segment Data',
#   '0x50',
#   'ELT',
#   'Segment data of a file to download.',
#   'N/A',
#   'Multi',
#   'Auto TM'],
#  ['Transfer File Upload Data',
#   '0x51',
#   'ELT',
#   'Segment data of a file to upload.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Transfer Image File List',
#   '0x83',
#   'PLT',
#   'Image file information List.',
#   'N/A',
#   'Multi',
#   'Auto TM'],
#  ['WOD Close',
#   '0x78',
#   'HKT',
#   'Stop WOD logging and close WOD file.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['WOD Configuration Set',
#   '0x79',
#   'HKT',
#   'Configure update frequency and list of telemetries of WOD file.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['WOD Info Request',
#   '0x7A',
#   'HKT',
#   'Get WOD configuration information.',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['WOD Restart',
#   '0x7B',
#   'HKT',
#   'Close current WOD file and start new WOD file.',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Load FCS Calibration Parameter File',
#   '0xA0',
#   'FCS',
#   'Load FCS Calibration Parameter File',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Dump All FCS Data',
#   '0xA3',
#   'FCS',
#   'Dump All FCS Data',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Auto AOCS Log File Period',
#   '0xB0',
#   'FCS',
#   'Set auto logging period of AOCS log file',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Manual AOCS Log File Logging',
#   '0xB1',
#   'FCS',
#   'Save manual AOCS data log file for specifiedperiod',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Stop Manual AOCS Log File Logging',
#   '0xB2',
#   'FCS',
#   'Stop or cancel manual AOCS data log file ',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Auto GPS Log File Period',
#   '0xB5',
#   'FCS',
#   'Set auto logging period of GPS log file',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Manual GPS Log File Logging',
#   '0xB6',
#   'FCS',
#   'Save manual GPS log file for specifiedperiod',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Stop Manual GPS Log File Logging',
#   '0xB7',
#   'FCS',
#   'Stop or cancel manual GPS log file ',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Auto STS Log File Period',
#   '0xBA',
#   'FCS',
#   'Set auto logging period of STS Data log file',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Manual STS Log File Logging',
#   '0xBB',
#   'FCS',
#   'Save manual STS data log file for specifiedperiod',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Stop Manual STS Log File Logging',
#   '0xBC',
#   'FCS',
#   'Stop or cancel manual STS data log file ',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set Manual Mag Calibration Log File Logging',
#   '0xC0',
#   'FCS',
#   'Start Mag Calibration Log File',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Stop Manual Mag Calibration Log File Logging',
#   '0xC1',
#   'FCS',
#   'Stop Mag Calibration Log File',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set KEPS Parameter',
#   '0xD0',
#   'FCS',
#   'Set KEPS Parameter',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set OD Method',
#   '0xD1',
#   'FCS',
#   'Set OD Method',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set FCS Control Frequency',
#   '0xD2',
#   'FCS',
#   'Set FCS Control Frequency',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set GPS Time Sync Enable/Disable Status',
#   '0xD3',
#   'FCS',
#   'Set GPS Time Sync Enable/Disable Status',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set GPS Leap Second',
#   '0xD4',
#   'FCS',
#   'Set GPS Leap Second',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set STS Fused Attitude Mode',
#   '0xD5',
#   'FCS',
#   'Set STS Fused Attitude Mode ',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Thruster Configuration Set',
#   '0xD7',
#   'FCS',
#   'Set Thruster Configuration',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['HW Test Mode Set',
#   '0xE0',
#   'FCS',
#   'Enable/Disable HW Test Mode',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set STS Operation Mode',
#   '0xE1',
#   'FCS',
#   'Set STS Operation Mode',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set RW Torque Command',
#   '0xE3',
#   'FCS',
#   'Set RW Torque Command',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set MTR Fire Command',
#   '0xE4',
#   'FCS',
#   'Set MTR Fire Command',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Set XAPM Position Command',
#   '0xE5',
#   'FCS',
#   'Set XAPM Position Command',
#   'Immediate',
#   'Single',
#   'Command'],
#  ['Integration Test Command',
#   '0x90',
#   'SYS',
#   'Debug TCs for FSW integration test',
#   'Immediate',
#   'Single',
#   'Info Request'],
#  ['FSW Operation Information',
#   '0x60',
#   'OMT',
#   'FSW operation information',
#   'N/A',
#   'Single',
#   'Auto TM'],
#  ['TIB',
#   '0x4D',
#   'ELT',
#   'All HW telemetries and sub-system information.',
#   'N/A',
#   'Multi',
#   'Auto TM'],
#  ['Internal Event Message',
#   '0x42',
#   'ELT',
#   'Collected event messages for 1 second.',
#   'N/A',
#   'Single',
#   'Auto TM']]

# %%
##Make TaskID DataFrame
taskid_value=[]
taskid_column=[]

taskid_column=th_list[0]
del th_list[0]

taskid_value=td_list

taskid=pd.DataFrame(columns=taskid_column)
for now in taskid_value:
    taskid.loc[len(taskid)]=now
taskid
# Out:
#                      Command Name Packet Type FSW Task  \
# 0                    AOCS ADS Set        0x32      ELT
# 1                  AOCS Power Set        0x33      ELT
# 2         Bootloader High FOS Run        0x00      SYS
# 3                Cancel File List        0x34      ELT
# 4    Cancel File Segment Download        0x35      ELT
# ..                            ...         ...      ...
# 100     Set XAPM Position Command        0xE5      FCS
# 101      Integration Test Command        0x90      SYS
# 102     FSW Operation Information        0x60      OMT
# 103                           TIB        0x4D      ELT
# 104        Internal Event Message        0x42      ELT
#
#     Description(Refer to GS Triggered Command for detailed information)  \
# 0                             Set ADS of AOCS modules.
# 1    Control power of AOCS module immediately, rega...
# 2                          Run FOS in Bootloader High.
# 3                     Cancel file list query sequence.
# 4                       Cancel file download sequence.
# ..                                                 ...
# 100                          Set XAPM Position Command
# 101                 Debug TCs for FSW integration test
# 102                          FSW operation information
# 103     All HW telemetries and sub-system information.
# 104             Collected event messages for 1 second.
#
#     Response Timing Response Number  Command Type
# 0         Immediate          Single       Command
# 1         Immediate          Single       Command
# 2         Immediate          Single       Command
# 3         Immediate          Single       Command
# 4         Immediate          Single       Command
# ..              ...             ...           ...
# 100       Immediate          Single       Command
# 101       Immediate          Single  Info Request
# 102             N/A          Single       Auto TM
# 103             N/A           Multi       Auto TM
# 104             N/A          Single       Auto TM
#
# [105 rows x 7 columns]

# %%
##Make Dataframe dictionary 준비
html_link="C:/Users/user/Desktop/FSWICD/TC/[ESGS] ADS(Active Device Selection) Management - SX FSW - Wiki SI.html"
dataframe_dic={}
split_str="<div class=\"conf-macro output-block\" data-hasbody=\"true\" data-macro-name=\"numberedheadings\">"
th_list=["Properties", "Packet Format", "Parameter Definition"]

def isNode(now):    

    if("Properties" in now): return ["TC/TM Type", "Sub Packet ID", "Formatter Name"]
    if("Packet Format" in now): return ["Start Address", "Length(bit)", "Name", "Data Type", "Default Value"]
    if("Parameter Definition" in now): return ["Name", "Description", "Parameter Type", "TM/TC Type", "Data Conversion", "Unit", "Category", "Normal Range", "Warning Range", "Symbolic Definition"]
    return -1

# %%
#Make count list -> 각 데이터프레임의 행 개수

split_str="<div class=\"conf-macro output-block\" data-hasbody=\"true\" data-macro-name=\"numberedheadings\">"
html_GSTriggered=open(html_link, 'r', encoding='UTF8')
soup=BeautifulSoup(html_GSTriggered, 'html.parser')
    

count_list=[]
h2_list=str(soup).split(split_str)[1].split("<h2 ")

h3_list=[]
for now in h2_list:
    if not ("Structure Format" in now):
        now_list=now.split("<h3")
        h3_list.append(now_list)

for now_list in h3_list:
    for now in now_list:
        now_column=isNode(now)
        if not(now_column==-1):
            count_list.append(int(now.count("</td>")/len(now_column)))
    
print(count_list)
print(len(count_list))
# Out:
# [1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2]
# 12

# %%
#Make title Dictionary -> structure 제외

h1_list=soup.find_all("h1")
h2_list=soup.find_all("h2")
title_dic={}

for h1 in h1_list:
    if(". " in h1.get_text()):
        now_h1=h1.get_text().split(". ")
        if not('Structure' in now_h1[1]):
            title_dic[now_h1[1]]=[]
            for h2 in h2_list:
                now_h2=h2.get_text().split(".")
                if(now_h1[0]==now_h2[0]):
                    child_dic={}
                    child_dic[now_h2[2].lstrip()]=[]
                    title_dic[now_h1[1]].append(child_dic)
                
title_dic
# Out:
# {'CAN Node ADS Set': [{'CAN Node ADS Set': []}],
#  'AOCS ADS Set': [{'AOCS ADS Set': []}],
#  'Network ADS Set': [{'Network ADS Set': []}],
#  'MISC ADS Set': [{'MISC ADS Set': []}]}

# %%
##html parsing
tr=soup.find_all("tr")
sp=soup.find_all("h1")

td_list=[]
h1_list=[]

for now in tr:
    td_find=now.find_all("td")
    if(td_find):
        td_now_list=[]
        for td in td_find:
            if(len(td_now_list)>8):
                sd_list=[]
                for sd in td.find_all("li"):
                    sd_list.append(sd.get_text().replace(u'\xa0', ''))
                td_now_list.append(', '.join(sd_list))

            else:
                if(td.get_text()):
                    td_now_list.append(td.get_text().replace(u'\xa0', ''))
                else:
                    td_now_list.append("")
        td_list.append(td_now_list)
        
td_list
# Out:
# [['TC', '0x00', ''],
#  ['D0', '8', 'CAN Node ADS Index', 'BYTE', ''],
#  ['D1', '8', 'CAN Node ADS Value', 'BYTE', ''],
#  ['CAN Node ADS Index',
#   'Index of CAN Node to set ADS',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0 - PPIB P, 1 - PPIB R, 2 - SPIB P, 3 - SPIB R, 4 - CIB P, 5 - CIB R, 6 -ICM P, 7 -ICM R, 8 - ACM P, 9 - ACM R, 10 - XTU1, 11 - XTU2, 14 - ACSIB P, 15 - ACSIB R, 16 - STS1, 17 - STS2, 18 - STS3, 19 - GPS P, 20 - GPS R, 21 - VCIB P, 22 - VCIB R'],
#  ['CAN Node ADS Value',
#   'ADS value to be set',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0x00 - Inactive, 0x01 - Active'],
#  ['TC', '0x00', ''],
#  ['D0', '8', 'AOCS ADS Index', 'BYTE', ''],
#  ['D1', '8', 'AOCS ADS Value', 'BYTE', ''],
#  ['AOCS ADS Index',
#   'Index of AOCS to set ADS',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0 - RW1, 1 - RW2, 2 - RW3, 3 - RW4, 4 - Gyro1, 5 - Gyro2, 6 - Gyro3, 7 - Gyro4, 8 - Gyro5, 9 - Gyro6, 10 - Gyro7, 11 - Gyro8, 12 - FSS1, 13 - FSS2, 14 - CSS, 15 - MAG1, 16 - MAG2, 17 - MT1, 18 - MT2, 19 - XAPM1, 20 - XAPM2'],
#  ['AOCS ADS Value',
#   'ADS value to be set',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0x00 - Inactive, 0x01 - Active'],
#  ['TC', '0x00', ''],
#  ['D0', '8', 'Network ADS Index', 'BYTE', ''],
#  ['D1', '8', 'Network ADS Value', 'BYTE', ''],
#  ['Network ADS Index',
#   'Index of Network to set ADS',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0 - CDH CAN P, 1 - CDH CAN R, 2 - ACS CAN P, 3 - ACS CAN R'],
#  ['Network ADS Value',
#   'ADS value to be set',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0x00 - Inactive, 0x01 - Active'],
#  ['TC', '0x00', ''],
#  ['D0', '8', 'MISC ADS Index', 'BYTE', ''],
#  ['D1', '8', 'MISC ADS Value', 'BYTE', ''],
#  ['MISC ADS Index',
#   'Index of the MISC to set ADS',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0 - GPS PPS P, 1 - GPS PPS R, 2 - CSS1 Data Selection, 3 - CSS2 Data Selection, 4 - CSS3 Data Selection, 5 - CSS4 Data Selection, 6 - CSS5 Data Selection, 7 - STS1 Data Selection, 8 - STS2 Data Selection, 9 - STS3 Data Selection, 10 - STS1 Internal CAN P, 11 - STS1 Internal CAN S, 12 - STS2 Internal CAN P, 13 - STS2 Internal CAN S, 14 - STS3 Internal CAN P, 15 - STS3 Internal CAN S, 16 - FPA1, 17 - FPA2, 18 - FPA3, 19 - SB1, 20 - SB2, 21 - SB3, 22 - SB4, 23 - EOS OPH Enable Switch P, 24 - EOS OPH Enable Switch R, 25 - EOS SVH Enable Switch, 26 - BUS OPH Enable Switch P, 27 - BUS OPH Enable Switch R, 28 - BAT OPH Enable Switch P, 29 - BAT OPH Enable Switch R, 30 - BAT SVH Enable Switch P, 31 - BAT SVH Enable Switch R, 32 - BCR1, 33 - BCR2, 34 - BCR3, 35 - STX1, 36 - STX2'],
#  ['MISC ADS Value',
#   'ADS value to be set',
#   'Symbolic',
#   'TC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0x00 - Inactive, 0x01 - Active']]

# %%
##remark 부분 삭제

#del_index=count_list[0]+count_list[1]

#print(td_list)

#for i in range(0,count_list[2]):
#    del td_list[del_index+i][len(td_list[del_index+i])-1]

# %%
##count에 맞추어 빈 테이블 존재 구간 삭제 밑준비

def list_chunk(lst, n):
    return [lst[i:i+n] for i in range(0, len(lst), n)]


td_list_count=[]
td_list_=td_list.copy()

###각 count를 3개씩 잘라서, td_list를 이에 맞게 나눈다
list_3=list_chunk(count_list, 3)

for now_list in list_3:
    parent_list=[]
    for row_count in now_list:
        child_list=[]
        for i in range(0, row_count):
            if(td_list_):
                child_list.append(td_list_[0])
                del td_list_[0]
        parent_list.append(child_list)
    td_list_count.append(parent_list)

# %%
###해당 list를 title dictionary와 합침.

td_list_count_=td_list_count.copy()



for outkey, outvalue in title_dic.items():
    for list_value in outvalue:
        for inkey, invalue in list_value.items():
            if(td_list_count_):
                list_value[inkey]=td_list_count_[0]
                del td_list_count_[0]

title_dic
# Out:
# {'CAN Node ADS Set': [{'CAN Node ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'CAN Node ADS Index', 'BYTE', ''],
#      ['D1', '8', 'CAN Node ADS Value', 'BYTE', '']],
#     [['CAN Node ADS Index',
#       'Index of CAN Node to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - PPIB P, 1 - PPIB R, 2 - SPIB P, 3 - SPIB R, 4 - CIB P, 5 - CIB R, 6 -ICM P, 7 -ICM R, 8 - ACM P, 9 - ACM R, 10 - XTU1, 11 - XTU2, 14 - ACSIB P, 15 - ACSIB R, 16 - STS1, 17 - STS2, 18 - STS3, 19 - GPS P, 20 - GPS R, 21 - VCIB P, 22 - VCIB R'],
#      ['CAN Node ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}],
#  'AOCS ADS Set': [{'AOCS ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'AOCS ADS Index', 'BYTE', ''],
#      ['D1', '8', 'AOCS ADS Value', 'BYTE', '']],
#     [['AOCS ADS Index',
#       'Index of AOCS to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - RW1, 1 - RW2, 2 - RW3, 3 - RW4, 4 - Gyro1, 5 - Gyro2, 6 - Gyro3, 7 - Gyro4, 8 - Gyro5, 9 - Gyro6, 10 - Gyro7, 11 - Gyro8, 12 - FSS1, 13 - FSS2, 14 - CSS, 15 - MAG1, 16 - MAG2, 17 - MT1, 18 - MT2, 19 - XAPM1, 20 - XAPM2'],
#      ['AOCS ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}],
#  'Network ADS Set': [{'Network ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'Network ADS Index', 'BYTE', ''],
#      ['D1', '8', 'Network ADS Value', 'BYTE', '']],
#     [['Network ADS Index',
#       'Index of Network to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - CDH CAN P, 1 - CDH CAN R, 2 - ACS CAN P, 3 - ACS CAN R'],
#      ['Network ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}],
#  'MISC ADS Set': [{'MISC ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'MISC ADS Index', 'BYTE', ''],
#      ['D1', '8', 'MISC ADS Value', 'BYTE', '']],
#     [['MISC ADS Index',
#       'Index of the MISC to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - GPS PPS P, 1 - GPS PPS R, 2 - CSS1 Data Selection, 3 - CSS2 Data Selection, 4 - CSS3 Data Selection, 5 - CSS4 Data Selection, 6 - CSS5 Data Selection, 7 - STS1 Data Selection, 8 - STS2 Data Selection, 9 - STS3 Data Selection, 10 - STS1 Internal CAN P, 11 - STS1 Internal CAN S, 12 - STS2 Internal CAN P, 13 - STS2 Internal CAN S, 14 - STS3 Internal CAN P, 15 - STS3 Internal CAN S, 16 - FPA1, 17 - FPA2, 18 - FPA3, 19 - SB1, 20 - SB2, 21 - SB3, 22 - SB4, 23 - EOS OPH Enable Switch P, 24 - EOS OPH Enable Switch R, 25 - EOS SVH Enable Switch, 26 - BUS OPH Enable Switch P, 27 - BUS OPH Enable Switch R, 28 - BAT OPH Enable Switch P, 29 - BAT OPH Enable Switch R, 30 - BAT SVH Enable Switch P, 31 - BAT SVH Enable Switch R, 32 - BCR1, 33 - BCR2, 34 - BCR3, 35 - STX1, 36 - STX2'],
#      ['MISC ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}]}

# %%
##빈 리스트를 가지는 모든 딕셔너리 삭제

del_list=[]

empty_list=[]
empty_dic={}

def list_dic_index(dic_list, key):
    for now in dic_list:
        if(key in now):
            return dic_list.index(now)
    return -1
            


###루프중 삭제가 불가능하므로 빈 키 이름을 모음
for outkey, outvalue in title_dic.items():
    for list_value in outvalue:
        for inkey, invalue in list_value.items():
            if(empty_list in invalue):
                del_list.append([outkey, inkey])

###삭제
for del_key in del_list:
    index=list_dic_index(title_dic[del_key[0]], del_key[1])
    del title_dic[del_key[0]][index]
    if not(title_dic[del_key[0]]):
        del title_dic[del_key[0]]
            
del_list
# Out:
# []

# %%
title_dic
# Out:
# {'CAN Node ADS Set': [{'CAN Node ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'CAN Node ADS Index', 'BYTE', ''],
#      ['D1', '8', 'CAN Node ADS Value', 'BYTE', '']],
#     [['CAN Node ADS Index',
#       'Index of CAN Node to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - PPIB P, 1 - PPIB R, 2 - SPIB P, 3 - SPIB R, 4 - CIB P, 5 - CIB R, 6 -ICM P, 7 -ICM R, 8 - ACM P, 9 - ACM R, 10 - XTU1, 11 - XTU2, 14 - ACSIB P, 15 - ACSIB R, 16 - STS1, 17 - STS2, 18 - STS3, 19 - GPS P, 20 - GPS R, 21 - VCIB P, 22 - VCIB R'],
#      ['CAN Node ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}],
#  'AOCS ADS Set': [{'AOCS ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'AOCS ADS Index', 'BYTE', ''],
#      ['D1', '8', 'AOCS ADS Value', 'BYTE', '']],
#     [['AOCS ADS Index',
#       'Index of AOCS to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - RW1, 1 - RW2, 2 - RW3, 3 - RW4, 4 - Gyro1, 5 - Gyro2, 6 - Gyro3, 7 - Gyro4, 8 - Gyro5, 9 - Gyro6, 10 - Gyro7, 11 - Gyro8, 12 - FSS1, 13 - FSS2, 14 - CSS, 15 - MAG1, 16 - MAG2, 17 - MT1, 18 - MT2, 19 - XAPM1, 20 - XAPM2'],
#      ['AOCS ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}],
#  'Network ADS Set': [{'Network ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'Network ADS Index', 'BYTE', ''],
#      ['D1', '8', 'Network ADS Value', 'BYTE', '']],
#     [['Network ADS Index',
#       'Index of Network to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - CDH CAN P, 1 - CDH CAN R, 2 - ACS CAN P, 3 - ACS CAN R'],
#      ['Network ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}],
#  'MISC ADS Set': [{'MISC ADS Set': [[['TC', '0x00', '']],
#     [['D0', '8', 'MISC ADS Index', 'BYTE', ''],
#      ['D1', '8', 'MISC ADS Value', 'BYTE', '']],
#     [['MISC ADS Index',
#       'Index of the MISC to set ADS',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0 - GPS PPS P, 1 - GPS PPS R, 2 - CSS1 Data Selection, 3 - CSS2 Data Selection, 4 - CSS3 Data Selection, 5 - CSS4 Data Selection, 6 - CSS5 Data Selection, 7 - STS1 Data Selection, 8 - STS2 Data Selection, 9 - STS3 Data Selection, 10 - STS1 Internal CAN P, 11 - STS1 Internal CAN S, 12 - STS2 Internal CAN P, 13 - STS2 Internal CAN S, 14 - STS3 Internal CAN P, 15 - STS3 Internal CAN S, 16 - FPA1, 17 - FPA2, 18 - FPA3, 19 - SB1, 20 - SB2, 21 - SB3, 22 - SB4, 23 - EOS OPH Enable Switch P, 24 - EOS OPH Enable Switch R, 25 - EOS SVH Enable Switch, 26 - BUS OPH Enable Switch P, 27 - BUS OPH Enable Switch R, 28 - BAT OPH Enable Switch P, 29 - BAT OPH Enable Switch R, 30 - BAT SVH Enable Switch P, 31 - BAT SVH Enable Switch R, 32 - BCR1, 33 - BCR2, 34 - BCR3, 35 - STX1, 36 - STX2'],
#      ['MISC ADS Value',
#       'ADS value to be set',
#       'Symbolic',
#       'TC',
#       '',
#       '',
#       '',
#       '',
#       '',
#       '0x00 - Inactive, 0x01 - Active']]]}]}

# %%
##json making

json_dic={}

for outkey, outvalue in title_dic.items():
    tc_list=[]
    tc_list.append({"Packet Type":outkey})
    
    for list_value in outvalue:
        for inkey, invalue in list_value.items():
            json_dic[inkey]={}
            tc_list.append({"Subpacket Type":inkey})
            tc_list.append({"Task ID":   str(taskid.loc[taskid["Command Name"]==inkey]["FSW Task"].values).split("'")[1]   })
            symbolicdef_list=[]
 
            data_list=[]
            for row in invalue[2]:##Parameter Definition
                symbolicdef_row_list=row[len(row)-1].split(", ")
                       
                for now in symbolicdef_row_list:
                    symbolicdef_row_list[symbolicdef_row_list.index(now)]=now.split("-")[1].lstrip()
                
                symbolicdef_list.append({row[0]:symbolicdef_row_list})
                data_list.append( {row[0]: "{"+str(invalue[2].index(row))+"}" })
                
            if(symbolicdef_list):
                json_dic[inkey]["SymbolicDef"]={}
                for now in symbolicdef_list:
                    json_dic[inkey]["SymbolicDef"].update(now)
            
            json_dic[inkey]["TC"]={}
            
            for now in tc_list:
                json_dic[inkey]["TC"].update(now)
                
                
            json_dic[inkey]["TC"]["Data"]={}
            for now in data_list:
                json_dic[inkey]["TC"]["Data"].update(now)
                
            
            
json_dic
# Out:
# {'CAN Node ADS Set': {'SymbolicDef': {'CAN Node ADS Index': ['PPIB P',
#     'PPIB R',
#     'SPIB P',
#     'SPIB R',
#     'CIB P',
#     'CIB R',
#     'ICM P',
#     'ICM R',
#     'ACM P',
#     'ACM R',
#     'XTU1',
#     'XTU2',
#     'ACSIB P',
#     'ACSIB R',
#     'STS1',
#     'STS2',
#     'STS3',
#     'GPS P',
#     'GPS R',
#     'VCIB P',
#     'VCIB R'],
#    'CAN Node ADS Value': ['Inactive', 'Active']},
#   'TC': {'Packet Type': 'CAN Node ADS Set',
#    'Subpacket Type': 'CAN Node ADS Set',
#    'Task ID': 'ELT',
#    'Data': {'CAN Node ADS Index': '{0}', 'CAN Node ADS Value': '{1}'}}},
#  'AOCS ADS Set': {'SymbolicDef': {'AOCS ADS Index': ['RW1',
#     'RW2',
#     'RW3',
#     'RW4',
#     'Gyro1',
#     'Gyro2',
#     'Gyro3',
#     'Gyro4',
#     'Gyro5',
#     'Gyro6',
#     'Gyro7',
#     'Gyro8',
#     'FSS1',
#     'FSS2',
#     'CSS',
#     'MAG1',
#     'MAG2',
#     'MT1',
#     'MT2',
#     'XAPM1',
#     'XAPM2'],
#    'AOCS ADS Value': ['Inactive', 'Active']},
#   'TC': {'Packet Type': 'AOCS ADS Set',
#    'Subpacket Type': 'AOCS ADS Set',
#    'Task ID': 'ELT',
#    'Data': {'AOCS ADS Index': '{0}', 'AOCS ADS Value': '{1}'}}},
#  'Network ADS Set': {'SymbolicDef': {'Network ADS Index': ['CDH CAN P',
#     'CDH CAN R',
#     'ACS CAN P',
#     'ACS CAN R'],
#    'Network ADS Value': ['Inactive', 'Active']},
#   'TC': {'Packet Type': 'Network ADS Set',
#    'Subpacket Type': 'Network ADS Set',
#    'Task ID': 'ELT',
#    'Data': {'Network ADS Index': '{0}', 'Network ADS Value': '{1}'}}},
#  'MISC ADS Set': {'SymbolicDef': {'MISC ADS Index': ['GPS PPS P',
#     'GPS PPS R',
#     'CSS1 Data Selection',
#     'CSS2 Data Selection',
#     'CSS3 Data Selection',
#     'CSS4 Data Selection',
#     'CSS5 Data Selection',
#     'STS1 Data Selection',
#     'STS2 Data Selection',
#     'STS3 Data Selection',
#     'STS1 Internal CAN P',
#     'STS1 Internal CAN S',
#     'STS2 Internal CAN P',
#     'STS2 Internal CAN S',
#     'STS3 Internal CAN P',
#     'STS3 Internal CAN S',
#     'FPA1',
#     'FPA2',
#     'FPA3',
#     'SB1',
#     'SB2',
#     'SB3',
#     'SB4',
#     'EOS OPH Enable Switch P',
#     'EOS OPH Enable Switch R',
#     'EOS SVH Enable Switch',
#     'BUS OPH Enable Switch P',
#     'BUS OPH Enable Switch R',
#     'BAT OPH Enable Switch P',
#     'BAT OPH Enable Switch R',
#     'BAT SVH Enable Switch P',
#     'BAT SVH Enable Switch R',
#     'BCR1',
#     'BCR2',
#     'BCR3',
#     'STX1',
#     'STX2'],
#    'MISC ADS Value': ['Inactive', 'Active']},
#   'TC': {'Packet Type': 'MISC ADS Set',
#    'Subpacket Type': 'MISC ADS Set',
#    'Task ID': 'ELT',
#    'Data': {'MISC ADS Index': '{0}', 'MISC ADS Value': '{1}'}}}}

# %%
with open("ESGSTCFormat.json", "w") as f:
    json.dump(json_dic, f, ensure_ascii=False, indent=4)
