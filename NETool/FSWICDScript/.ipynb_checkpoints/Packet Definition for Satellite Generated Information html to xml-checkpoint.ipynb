# %%
from bs4 import BeautifulSoup
import pandas as pd
from html_table_parser import parser_functions as parser
from xml.etree.ElementTree import Element, dump
from xml.etree.ElementTree import ElementTree

# %%
#FSWOperationInformation.xml 

##read html
html_FSWO=open("C:/Users/user/Desktop/FSWICD/FSWOPInfo/[ESGS] FSW Operation Information - SX FSW - Wiki SI.html", 'r', encoding='UTF8')
soup=BeautifulSoup(html_FSWO, 'html.parser')

# %%
#html to string -> 각 table별 개수 파악
count_list=[]

split_str="<div class=\"conf-macro output-block\" data-hasbody=\"true\" data-macro-name=\"numberedheadings\">"
h3_list=str(soup).split(split_str)[1].split("<h3 ")

del h3_list[0]

for now in h3_list:
    ## th가 2개 들어 있으므로, 2로 한번 더 나눠줌
    count_list.append(int(now.count("</td>")/(now.count("</th>")/2)))
    
del count_list[0]
print(count_list)
# Out:
# [107, 99, 7, 7]

# %%
##html parsing -> xml용 dataframe 제작
tr=soup.find_all("tr")
td_list=[]
th_list=[]

for now in tr:
    th_find=now.find_all("th")
    td_find=now.find_all("td")
    if(th_find):
        th_list.append(th_find)
    if(td_find):
        td_list.append(td_find)

# %%
##필요한 부분까지 자르기

while(th_list):
    now_list=th_list[0]
    if(now_list[0].get_text()=='Start Address'):
        break
    del th_list[0]

while(td_list):
    now_list=td_list[0]
    if(now_list[0].get_text()=='D0'):
        break
    del td_list[0]

# %%
##Make Packet Format

Paket_column=[]
Paket_value=[]

for data in th_list[0]:
    Paket_column.append(data.get_text())
    
del th_list[0];
del th_list[0];

while(1):
    Paket_value_list=[];
    for data in td_list[0]:
        Paket_value_list.append(data.get_text())
    Paket_value.append(Paket_value_list)
    
    ##표 끝값이 나오면 정지
    if(len(Paket_value)==count_list[0]):
        del td_list[0]
        del count_list[0]
        break
    del td_list[0]
    
Paket=pd.DataFrame(columns=Paket_column)

for now in Paket_value:
    Paket.loc[len(Paket)]=now
Paket
# Out:
#     Start Address Length(bit)                         Name Data Type  \
# 0              D0          32       Current Satellite Time    UINT32
# 1              D4          32  Elapsed Time since OBC Boot    UINT32
# 2              D8           8                   OBC Number      BYTE
# 3              D9           8             OBC Reset Reason      BYTE
# 4           D10:7           4         ACS CAN BUS P Status      BYTE
# ..            ...         ...                          ...       ...
# 102          D185           8                      XAPM ID      BYTE
# 103          D186           8                     Reserved      BYTE
# 104          D187           8                     Reserved      BYTE
# 105          D188          32           XAPM Azimuth Angle     FLOAT
# 106          D192          32         XAPM Elevation Angle     FLOAT
#
#     Default Value
# 0
# 1
# 2
# 3
# 4
# ..            ...
# 102
# 103
# 104
# 105
# 106
#
# [107 rows x 5 columns]

# %%
##Make Parameter Definition

Parameter_column=[]
Parameter_value=[]

for data in th_list[0]:
    if(th_list):
        Parameter_column.append(data.get_text())
    
del th_list[0];
del th_list[0];

while(td_list):
    Parameter_value_list=[]
    Symbolic_list=[]
    
    for data in td_list[0]:
        ##Symbolic definition은 여러 값을 가지므로, list로 개별 처리
        if(len(Parameter_value_list)<=8):
            Parameter_value_list.append(data.get_text())
        else:
            if(data.find_all('li')):
                for symbolic_value in data.find_all('li'):
                    Symbolic_list.append(symbolic_value.get_text())
                                     
    Parameter_value_list.append(", ".join(map(str, Symbolic_list)))
    Parameter_value.append(Parameter_value_list)
    
    ##표 끝값이 나오면 break
    if(len(Parameter_value)==count_list[0]):
        del count_list[0]
        break
    del td_list[0]
    
Parameter=pd.DataFrame(columns=Parameter_column)
for now in Parameter_value:
    Parameter.loc[len(Parameter)]=now
Parameter
# Out:
#                             Name  \
# 0         Current Satellite Time
# 1    Elapsed Time since OBC Boot
# 2                     OBC Number
# 3               OBC Reset Reason
# 4           ACS CAN BUS P Status
# ..                           ...
# 94         PLT file delete state
# 95  PLT file system format state
# 96                       XAPM ID
# 97            XAPM Azimuth Angle
# 98          XAPM Elevation Angle
#
#                                           Description Parameter Type  \
# 0   Current Satellite Time. This value is updated ...        Numeric
# 1   Elapsed Time since OBC Boot. This value is upd...        Numeric
# 2          This value is updated in 1Hz event of OMT.       Symbolic
# 3          This value is updated in 1Hz event of OMT.       Symbolic
# 4          This value is updated in 1Hz event of OMT.       Symbolic
# ..                                                ...            ...
# 94         This value is updated in 1Hz event of PLT.       Symbolic
# 95         This value is updated in 1Hz event of PLT.       Symbolic
# 96                    ID of the currently active XAPM       Symbolic
# 97          Current azimuth angle of the active XAPM         Numeric
# 98        Current elevation angle of the active XAPM         Numeric
#
#    TM/TC Type Data Conversion    Unit     Category             Normal Range  \
# 0          TM                  Second         Time  0x21DAE500 - 0xFFFFFFFF
# 1          TM                  Second         Time           0 - 0xFFFFFFFF
# 2          TM                           OBC Status
# 3          TM                           OBC Status
# 4          TM                           OBC Status
# ..        ...             ...     ...          ...                      ...
# 94         TM                          Task Status
# 95         TM                          Task Status
# 96    TC & TM
# 97    TC & TM                     deg                            -270 - 270
# 98    TC & TM                     deg                            -110 - 110
#
#    Warning Range                                Symbolic Definition
# 0
# 1
# 2                                          0x00 - OBC1, 0x01 - OBC2
# 3                          0x00 - TMTC Reset, 0x01 - Power on Reset
# 4                 0x00 - ERROR_ACTIVE, 0x01 - ERROR_PASSIVE, 0x0...
# ..           ...                                                ...
# 94                100 - FDL_ST_NONE, 101 - FDL_ST_SSR_INIT, 102 ...
# 95                120 - FSF_ST_NONE , 121 - FSF_ST_SSR_ON, 122 -...
# 96                                            0 - XAPM1, 1 - XAPM2
# 97
# 98
#
# [99 rows x 10 columns]

# %%
##merging
merge=pd.merge(Paket, Parameter, how='left', on=None)
merge
# Out:
#     Start Address Length(bit)                         Name Data Type  \
# 0              D0          32       Current Satellite Time    UINT32
# 1              D4          32  Elapsed Time since OBC Boot    UINT32
# 2              D8           8                   OBC Number      BYTE
# 3              D9           8             OBC Reset Reason      BYTE
# 4           D10:7           4         ACS CAN BUS P Status      BYTE
# ..            ...         ...                          ...       ...
# 102          D185           8                      XAPM ID      BYTE
# 103          D186           8                     Reserved      BYTE
# 104          D187           8                     Reserved      BYTE
# 105          D188          32           XAPM Azimuth Angle     FLOAT
# 106          D192          32         XAPM Elevation Angle     FLOAT
#
#     Default Value                                        Description  \
# 0                  Current Satellite Time. This value is updated ...
# 1                  Elapsed Time since OBC Boot. This value is upd...
# 2                         This value is updated in 1Hz event of OMT.
# 3                         This value is updated in 1Hz event of OMT.
# 4                         This value is updated in 1Hz event of OMT.
# ..            ...                                                ...
# 102                                  ID of the currently active XAPM
# 103                                                              NaN
# 104                                                              NaN
# 105                        Current azimuth angle of the active XAPM
# 106                      Current elevation angle of the active XAPM
#
#     Parameter Type TM/TC Type Data Conversion    Unit    Category  \
# 0          Numeric         TM                  Second        Time
# 1          Numeric         TM                  Second        Time
# 2         Symbolic         TM                          OBC Status
# 3         Symbolic         TM                          OBC Status
# 4         Symbolic         TM                          OBC Status
# ..             ...        ...             ...     ...         ...
# 102       Symbolic    TC & TM
# 103            NaN        NaN             NaN     NaN         NaN
# 104            NaN        NaN             NaN     NaN         NaN
# 105        Numeric    TC & TM                     deg
# 106        Numeric    TC & TM                     deg
#
#                 Normal Range Warning Range  \
# 0    0x21DAE500 - 0xFFFFFFFF
# 1             0 - 0xFFFFFFFF
# 2
# 3
# 4
# ..                       ...           ...
# 102
# 103                      NaN           NaN
# 104                      NaN           NaN
# 105               -270 - 270
# 106               -110 - 110
#
#                                    Symbolic Definition
# 0
# 1
# 2                             0x00 - OBC1, 0x01 - OBC2
# 3             0x00 - TMTC Reset, 0x01 - Power on Reset
# 4    0x00 - ERROR_ACTIVE, 0x01 - ERROR_PASSIVE, 0x0...
# ..                                                 ...
# 102                              0 - XAPM1, 1 - XAPM2
# 103                                                NaN
# 104                                                NaN
# 105
# 106
#
# [107 rows x 14 columns]

# %%
##make datacolumn
column={'Type':[], 'Len':[], 'Unit':[], 'FieldName':[], 'NormalRange':[], 'Description':[], 'ValueMean':[]}
table_FSWO=pd.DataFrame(column)
table_FSWO['Type']=merge['Data Type']
table_FSWO['Len']=merge['Length(bit)']
table_FSWO['Unit']=merge['Unit']
table_FSWO['FieldName']=merge['Name']
table_FSWO['NormalRange']=merge['Normal Range']
table_FSWO['Description']=merge['Description']
table_FSWO['ValueMean']=merge['Symbolic Definition']
table_FSWO
# Out:
#        Type Len    Unit                    FieldName              NormalRange  \
# 0    UINT32  32  Second       Current Satellite Time  0x21DAE500 - 0xFFFFFFFF
# 1    UINT32  32  Second  Elapsed Time since OBC Boot           0 - 0xFFFFFFFF
# 2      BYTE   8                           OBC Number
# 3      BYTE   8                     OBC Reset Reason
# 4      BYTE   4                 ACS CAN BUS P Status
# ..      ...  ..     ...                          ...                      ...
# 102    BYTE   8                              XAPM ID
# 103    BYTE   8     NaN                     Reserved                      NaN
# 104    BYTE   8     NaN                     Reserved                      NaN
# 105   FLOAT  32     deg           XAPM Azimuth Angle               -270 - 270
# 106   FLOAT  32     deg         XAPM Elevation Angle               -110 - 110
#
#                                            Description  \
# 0    Current Satellite Time. This value is updated ...
# 1    Elapsed Time since OBC Boot. This value is upd...
# 2           This value is updated in 1Hz event of OMT.
# 3           This value is updated in 1Hz event of OMT.
# 4           This value is updated in 1Hz event of OMT.
# ..                                                 ...
# 102                    ID of the currently active XAPM
# 103                                                NaN
# 104                                                NaN
# 105          Current azimuth angle of the active XAPM
# 106        Current elevation angle of the active XAPM
#
#                                              ValueMean
# 0
# 1
# 2                             0x00 - OBC1, 0x01 - OBC2
# 3             0x00 - TMTC Reset, 0x01 - Power on Reset
# 4    0x00 - ERROR_ACTIVE, 0x01 - ERROR_PASSIVE, 0x0...
# ..                                                 ...
# 102                              0 - XAPM1, 1 - XAPM2
# 103                                                NaN
# 104                                                NaN
# 105
# 106
#
# [107 rows x 7 columns]

# %%
##dataframe 값 양식에 맞게 수정

for i in table_FSWO.index:
    now= table_FSWO.iloc[i].copy()
    now['Type']=now['Type'].replace('\n','')
    if('BYTE' in now['Type']):
        now['Type']='Byte'
    if('FLOAT' in now['Type']):
        now['Type']='Single'
    now['Type']="System."+now['Type']
    now['Len']=int(int(now['Len'])/8)
    now['NormalRange']=str(now['NormalRange']).replace('\n','')
    now_NormalRange_list=now['NormalRange'].split()
    if(len(now_NormalRange_list)>1):
        now['NormalRange']=now_NormalRange_list[0]+";"+now_NormalRange_list[2]
    ##수정값 반영
    table_FSWO.iloc[i]=now

table_FSWO
# Out:
#               Type Len    Unit                    FieldName  \
# 0    System.UINT32   4  Second       Current Satellite Time
# 1    System.UINT32   4  Second  Elapsed Time since OBC Boot
# 2      System.Byte   1                           OBC Number
# 3      System.Byte   1                     OBC Reset Reason
# 4      System.Byte   0                 ACS CAN BUS P Status
# ..             ...  ..     ...                          ...
# 102    System.Byte   1                              XAPM ID
# 103    System.Byte   1     NaN                     Reserved
# 104    System.Byte   1     NaN                     Reserved
# 105  System.Single   4     deg           XAPM Azimuth Angle
# 106  System.Single   4     deg         XAPM Elevation Angle
#
#                NormalRange                                        Description  \
# 0    0x21DAE500;0xFFFFFFFF  Current Satellite Time. This value is updated ...
# 1             0;0xFFFFFFFF  Elapsed Time since OBC Boot. This value is upd...
# 2                                  This value is updated in 1Hz event of OMT.
# 3                                  This value is updated in 1Hz event of OMT.
# 4                                  This value is updated in 1Hz event of OMT.
# ..                     ...                                                ...
# 102                                           ID of the currently active XAPM
# 103                    nan                                                NaN
# 104                    nan                                                NaN
# 105               -270;270          Current azimuth angle of the active XAPM
# 106               -110;110        Current elevation angle of the active XAPM
#
#                                              ValueMean
# 0
# 1
# 2                             0x00 - OBC1, 0x01 - OBC2
# 3             0x00 - TMTC Reset, 0x01 - Power on Reset
# 4    0x00 - ERROR_ACTIVE, 0x01 - ERROR_PASSIVE, 0x0...
# ..                                                 ...
# 102                              0 - XAPM1, 1 - XAPM2
# 103                                                NaN
# 104                                                NaN
# 105
# 106
#
# [107 rows x 7 columns]

# %%
##dataframe to xml
root_node=Element("FSWOperationInformation")


for i in table_FSWO.index:
        
    now= table_FSWO.iloc[i].copy()
    parent_node=Element("AlphanumericInfo")
    
    value_node=Element("Value");
    value_node.text="0";
    parent_node.append(value_node)
    
    for x in table_FSWO.columns:
        if(x=="ValueMean"):
            if(now[x]):
                for list_now in str(now[x]).split(', '):
                    valuemean_node=Element(x)
                    value_node=Element("Value")
                    mean_node=Element("Mean")
                    
                    list_now=list_now.replace(u'\xa0',' ')
                    list_ = list_now.split(' - ')
                    if('x' in list_[0]):
                        value_node.text=str(int(list_[0], 16))
                    else:
                        value_node.text=list_[0]
                    
                    if(len(list_)>1):
                        mean_node.text=list_[1]
                
                    valuemean_node.append(value_node)
                    valuemean_node.append(mean_node)
                
                    parent_node.append(valuemean_node)
        
        else:
            node=Element(x)
            if(str(now[x])):
                node.text=str(now[x]).replace(u'&#160;', ' ')
            else: 
                node.text=""
            parent_node.append(node)
   
    root_node.append(parent_node)

    
##xml 여백 추가
def indent(elem, level=0):
    i = "\n" + level*"  "
    if len(elem):
        if not elem.text or not elem.text.strip():
            elem.text = i + "  "
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
        for elem in elem:
            indent(elem, level+1)
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
    else:
        if level and (not elem.tail or not elem.tail.strip()):
            elem.tail = i

indent(root_node)
dump(root_node)
# Out:
# <FSWOperationInformation>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit>Second</Unit>
#     <FieldName>Current Satellite Time</FieldName>
#     <NormalRange>0x21DAE500;0xFFFFFFFF</NormalRange>
#     <Description>Current Satellite Time. This value is updated in 1Hz event of OMT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit>Second</Unit>
#     <FieldName>Elapsed Time since OBC Boot</FieldName>
#     <NormalRange>0;0xFFFFFFFF</NormalRange>
#     <Description>Elapsed Time since OBC Boot. This value is updated in 1Hz event of OMT</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>OBC Number</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>OBC1</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>OBC2</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>OBC Reset Reason</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>TMTC Reset</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Power on Reset</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>ACS CAN BUS P Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>ERROR_ACTIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>ERROR_PASSIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>BUS_OFF</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>ACS CAN BUS S Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>ERROR_ACTIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>ERROR_PASSIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>BUS_OFF</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>CDH CAN BUS P Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>ERROR_ACTIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>ERROR_PASSIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>BUS_OFF</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>CDH CAN BUS S Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>ERROR_ACTIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>ERROR_PASSIVE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>BUS_OFF</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>EDAC Handling Count</FieldName>
#     <NormalRange>0;255</NormalRange>
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>OMT System Mode</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of OMT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>INIT_POWER_ON</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>INIT_DETUMBLING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>SP_DEPLOYMENT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>AO_CAPTURE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>HOUSEKEEPING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>5</Value>
#       <Mean>SCENARIO</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>PARAMETER_UPDATE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>7</Value>
#       <Mean>POWER_THERMAL_SAFEHOLD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>AOCS_SAFEHOLD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>9</Value>
#       <Mean>CDH_NETWORK_SAFEHOLD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>10</Value>
#       <Mean>ACS_NETWORK_SAFEHOLD </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>File Upload Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of ELT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>Idle</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Uploading</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>File Download Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of ELT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>Idle</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Downloading</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>SRAM Free Space Size</FieldName>
#     <NormalRange>0;1048576</NormalRange>
#     <Description>Free Space Size in File System(SRAM). This value is updated in 1Hz event of OMT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>SDRAM Free Space Size</FieldName>
#     <NormalRange>0;268435456</NormalRange>
#     <Description>Free Space Size in File System(SDRAM). This value is updated in 1Hz event of OMT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Task Status Structure</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>Task Status</FieldName>
#     <NormalRange />
#     <Description>Task Status of FST.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>FCS AOCS Mode</FieldName>
#     <NormalRange />
#     <Description>FCS AOCS Mode</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>AOCS_INITIAL_POWER_ON</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>AOCS_INITIAL_DETUMBLING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>AOCS_SP_DEPLOYMENT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>AOCS_SUN_CAPTURE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>AOCS_SUN_TRACKING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>5</Value>
#       <Mean>AOCS_EARTH_POINTING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>AOCS_STRIP_IMAGING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>7</Value>
#       <Mean>AOCS_AIS_IMAGING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>AOCS_CELESTIAL_IMAGING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>9</Value>
#       <Mean>AOCS_CALIBRATION_MANEUVER</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>10</Value>
#       <Mean>AOCS_ORBIT_MAINTENANCE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>11</Value>
#       <Mean>AOCS_SAFEHOLD</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>FCS Control Frequency</FieldName>
#     <NormalRange />
#     <Description>FCS current control frequency</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>1 Hz</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>8 Hz</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>AOCS AD Method</FieldName>
#     <NormalRange />
#     <Description>AOCS AD Method</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>AD_NO_DETER</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>AD_DETUMBLING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>AD_SS_ONLY</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>AD_SS_GYRO</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>AD_FINE_3D</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>5</Value>
#       <Mean>AD_GYRO_ONLY</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>AD_HW_TEST</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>AOCS AC Method</FieldName>
#     <NormalRange />
#     <Description>AOCS AC Method</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>AC_NO_CONTROL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>AC_DETUMBLING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>AC_SUN_CAPTURE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>AC_SUN_TRACKING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>AC_EARTH_POINTING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>5</Value>
#       <Mean>AC_STRIP_IMAGING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>AC_AIS_IMAGING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>7</Value>
#       <Mean>AC_CELESTIAL_IMAGING</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>AC_CALIBRATION_MANEUVER</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>9</Value>
#       <Mean>AC_ORBIT_MAINTENANCE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>10</Value>
#       <Mean>AC_HW_TEST</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit>nan</Unit>
#     <FieldName>AOCS OD Method</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STx Control Mode</FieldName>
#     <NormalRange />
#     <Description>Mode to control STx On/Off status.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>STx Off Mode</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>STx On Mode</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>STx Control Mode</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>CAN LDB Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of ILT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>IDLE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>LDT_Transfer</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>FCS LDB Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of ILT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>IDLE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>LDT_Transfer</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>Eclipse Status</FieldName>
#     <NormalRange />
#     <Description>Sunlit / Eclipse status, based on the current OBC time and the orbit information</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>ECLIPSE_REGION</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>SUNLIT_REGION</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>DO_NOT_KNOW</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit>Second</Unit>
#     <FieldName>Current AOS</FieldName>
#     <NormalRange>0x21DAE500;0xFFFFFFFF</NormalRange>
#     <Description>This value is updated in 1Hz event of HKT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit>Second</Unit>
#     <FieldName>Current LOS</FieldName>
#     <NormalRange>0x21DAE500;0xFFFFFFFF</NormalRange>
#     <Description>This value is updated in 1Hz event of HKT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.INT32</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>q_1 of Estimated Quaternion</FieldName>
#     <NormalRange>-1;1</NormalRange>
#     <Description>Estimated quaternion between the body frame and the ECI frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.INT32</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>q_2 of Estimated Quaternion</FieldName>
#     <NormalRange>-1;1</NormalRange>
#     <Description>Estimated quaternion between the body frame and the ECI frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.INT32</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>q_3 of Estimated Quaternion</FieldName>
#     <NormalRange>-1;1</NormalRange>
#     <Description>Estimated quaternion between the body frame and the ECI frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.INT32</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>q_4 of Estimated Quaternion</FieldName>
#     <NormalRange>-1;1</NormalRange>
#     <Description>Estimated quaternion between the body frame and the ECI frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>X axis of Estimated Body Rate</FieldName>
#     <NormalRange>-15;+15</NormalRange>
#     <Description>Estimated body rate vector w.r.t. the body frame </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Y axis of Estimated Body Rate</FieldName>
#     <NormalRange>-15;+15</NormalRange>
#     <Description>Estimated body rate vector w.r.t. the body frame </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Z axis of Estimated Body Rate</FieldName>
#     <NormalRange>-15;+15</NormalRange>
#     <Description>Estimated body rate vector w.r.t. the body frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg</Unit>
#     <FieldName>Attitude Control Error</FieldName>
#     <NormalRange>-180;180</NormalRange>
#     <Description>Norm of estimated attitude control error angle</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Rate Control Error</FieldName>
#     <NormalRange>-15;15</NormalRange>
#     <Description>Norm of estimated rate control error</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>km</Unit>
#     <FieldName>X axis of Estimated Position</FieldName>
#     <NormalRange>-10,000;+10,000</NormalRange>
#     <Description>Estimated orbital position vector w.r.t. ECI frame </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>km</Unit>
#     <FieldName>Y axis of Estimated Position</FieldName>
#     <NormalRange>-10,000;+10,000</NormalRange>
#     <Description>Estimated orbital position vector w.r.t. ECI frame </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>km</Unit>
#     <FieldName>Z axis of Estimated Position</FieldName>
#     <NormalRange>-10,000;+10,000</NormalRange>
#     <Description>Estimated orbital position vector w.r.t. ECI frame </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>km/s</Unit>
#     <FieldName>X axis of Estimated Velocity</FieldName>
#     <NormalRange>-11.2;+11.2</NormalRange>
#     <Description>Estimated orbital velocity vector w.r.t. ECI frame </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>km/s</Unit>
#     <FieldName>Y axis of Estimated Velocity</FieldName>
#     <NormalRange>-11.2;+11.2</NormalRange>
#     <Description>Estimated orbital velocity vector w.r.t. ECI frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>km/s</Unit>
#     <FieldName>Z axis of Estimated Velocity</FieldName>
#     <NormalRange>-11.2;+11.2</NormalRange>
#     <Description>Estimated orbital velocity vector w.r.t. ECI frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>GPS 3D Fix Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of FCS.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>NO_3D_FIX</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>OK_3D_FIX </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>GPS PPS Selection</FieldName>
#     <NormalRange />
#     <Description>Current OBC PPS Source </Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>GPS_PPS_PRIMARY</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>GPS_PPS_SECONDARY</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>GPS_PPS_DISUSE</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>GPS PPS Lock</FieldName>
#     <NormalRange />
#     <Description>Current OBC PPS Sync Status</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>Not Synced</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Synced</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>GPS Receiver Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of FCS.</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>FPGA Reset Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Time Jump Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>Invalid PV Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>PR Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>3D Fix Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>SigTrack Operation Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>64</Value>
#       <Mean>NavTask Operation Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>128</Value>
#       <Mean>Watch Dog Flag </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>GPS Receiver Status of per day</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of FCS.</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>FPGA Reset Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Time Jump Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>Invalid PV Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>PR Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>3D Fix Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>SigTrack Operation Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>64</Value>
#       <Mean>NavTask Operation Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>128</Value>
#       <Mean>Watch Dog Flag </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>GPS Application Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of FCS.</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Navigation Converge Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Local Search Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>Setting Clock Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>TOE Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>Navigation Stable Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>64</Value>
#       <Mean>PV Available Flag </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>GPS Standard Positioning Service Status</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>GPS Orbit Determination Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of FCS.</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>OD Converge Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Jerk Detection Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>OD Converge Fail Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>Covariance Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>OD Error Flag</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>64</Value>
#       <Mean>PV Type : Estimation</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>128</Value>
#       <Mean>PV Type : OD </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>GPS CAN Communication Status</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of FCS.</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Int. Rx</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Int. Tx</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>Err. Warn</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>Data Overflow</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>Wake Up</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>Err. Passive</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>64</Value>
#       <Mean>Arbitrary Lost</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>128</Value>
#       <Mean>Bus Err. </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>GPS Tracking Satellite Count L1</FieldName>
#     <NormalRange>0;15</NormalRange>
#     <Description>GPS Tracking Satellite L1</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>GPS Tracking Satellite Count L2</FieldName>
#     <NormalRange>0;15</NormalRange>
#     <Description>GPS Tracking Satellite L2</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>Sun Sensor ID</FieldName>
#     <NormalRange />
#     <Description>ID of Sun Sensor with a valid sun vector measurement</Description>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>FSS1</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>FSS2</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>CSS1</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>CSS2</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>5</Value>
#       <Mean>CSS3</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>CSS4</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>7</Value>
#       <Mean>CSS5 </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>X axis of Sun Vector</FieldName>
#     <NormalRange>-1;+1</NormalRange>
#     <Description>Normalized Sun Vector w.r.t. Body Frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>Y axis of Sun Vector</FieldName>
#     <NormalRange>-1;+1</NormalRange>
#     <Description>Normalized Sun Vector w.r.t. Body Frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit />
#     <FieldName>Z axis of Sun Vector</FieldName>
#     <NormalRange>-1;+1</NormalRange>
#     <Description>Normalized Sun Vector w.r.t. Body Frame</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Active Gyro 1 Angular Rate</FieldName>
#     <NormalRange>-15;15</NormalRange>
#     <Description>Active Gyro 1 Angular Rate</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Active Gyro 2 Angular Rate</FieldName>
#     <NormalRange>-15;15</NormalRange>
#     <Description>Active Gyro 2 Angular Rate</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Active Gyro 3 Angular Rate</FieldName>
#     <NormalRange>-15;15</NormalRange>
#     <Description>Active Gyro 3 Angular Rate</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg/s</Unit>
#     <FieldName>Active Gyro 4 Angular Rate</FieldName>
#     <NormalRange>-15;15</NormalRange>
#     <Description>Active Gyro 4 Angular Rate</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>Active Gyro 1 ID</FieldName>
#     <NormalRange>0;7</NormalRange>
#     <Description>Active Gyro 1 ID with a valid STMR</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>Active Gyro 2 ID</FieldName>
#     <NormalRange>0;7</NormalRange>
#     <Description>Active Gyro 2 ID with a valid STMR</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>Active Gyro 3 ID</FieldName>
#     <NormalRange>0;7</NormalRange>
#     <Description>Active Gyro 3 ID with a valid STMR</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>Active Gyro 4 ID</FieldName>
#     <NormalRange>0;7</NormalRange>
#     <Description>Active Gyro 4 ID with a valid STMR</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS ID</FieldName>
#     <NormalRange />
#     <Description>ID of the current master STS, communicating with OBC</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>NONE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>STS1</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>STS2</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>STS3</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit>nan</Unit>
#     <FieldName>STS Attitude Update Frequency</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit>nan</Unit>
#     <FieldName>STS Attitude Frame Count Number</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS1 Attitude Operation Status</FieldName>
#     <NormalRange />
#     <Description>STS1 Operation status</Description>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>IMAGE_PROC_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>17</Value>
#       <Mean>NO_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>18</Value>
#       <Mean>TOO_FEW_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>19</Value>
#       <Mean>TOO_MANY_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>20</Value>
#       <Mean>NO_MEASURED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>21</Value>
#       <Mean>NOT_ENOUGH_MEASURED_STAR_FOR_MATCH</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>22</Value>
#       <Mean>NOT_ENOUGH_MEASURED_STAR_FOR_TRACK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>ID_PROC_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>33</Value>
#       <Mean>NO_VALID_GRID_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>34</Value>
#       <Mean>TOO_FEW_MATCHED_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>35</Value>
#       <Mean>NO_MATCHED_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>36</Value>
#       <Mean>NO_IDENTIFIED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>37</Value>
#       <Mean>NOT_ENOUGH_IDENTIFIED_STARS_FOR_AD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>38</Value>
#       <Mean>NOT_GUARANTEE_IDENTIFIED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>39</Value>
#       <Mean>NO_VALID_NEXT_TRACKING_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>40</Value>
#       <Mean>NOT_ENOUGH_VALID_NEXT_TRACKING_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>41</Value>
#       <Mean>NO_VALID_ROI_DATA</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>48</Value>
#       <Mean>ATTITUDE_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>49</Value>
#       <Mean>ATTITUDE_ACQ_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>50</Value>
#       <Mean>ATTITUDE_TRK_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>51</Value>
#       <Mean>ATTITUDE_NOT_ENOUGH_VECTOR_SET</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>52</Value>
#       <Mean>ATTITUDE_NOT_GUARANTEE</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS2 Attitude Operation Status</FieldName>
#     <NormalRange />
#     <Description>STS2 Operation status</Description>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>IMAGE_PROC_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>17</Value>
#       <Mean>NO_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>18</Value>
#       <Mean>TOO_FEW_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>19</Value>
#       <Mean>TOO_MANY_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>20</Value>
#       <Mean>NO_MEASURED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>21</Value>
#       <Mean>NOT_ENOUGH_MEASURED_STAR_FOR_MATCH</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>22</Value>
#       <Mean>NOT_ENOUGH_MEASURED_STAR_FOR_TRACK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>ID_PROC_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>33</Value>
#       <Mean>NO_VALID_GRID_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>34</Value>
#       <Mean>TOO_FEW_MATCHED_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>35</Value>
#       <Mean>NO_MATCHED_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>36</Value>
#       <Mean>NO_IDENTIFIED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>37</Value>
#       <Mean>NOT_ENOUGH_IDENTIFIED_STARS_FOR_AD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>38</Value>
#       <Mean>NOT_GUARANTEE_IDENTIFIED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>39</Value>
#       <Mean>NO_VALID_NEXT_TRACKING_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>40</Value>
#       <Mean>NOT_ENOUGH_VALID_NEXT_TRACKING_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>41</Value>
#       <Mean>NO_VALID_ROI_DATA</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>48</Value>
#       <Mean>ATTITUDE_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>49</Value>
#       <Mean>ATTITUDE_ACQ_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>50</Value>
#       <Mean>ATTITUDE_TRK_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>51</Value>
#       <Mean>ATTITUDE_NOT_ENOUGH_VECTOR_SET</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>52</Value>
#       <Mean>ATTITUDE_NOT_GUARANTEE</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS3 Attitude Operation Status</FieldName>
#     <NormalRange />
#     <Description>STS3 Operation status</Description>
#     <ValueMean>
#       <Value>16</Value>
#       <Mean>IMAGE_PROC_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>17</Value>
#       <Mean>NO_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>18</Value>
#       <Mean>TOO_FEW_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>19</Value>
#       <Mean>TOO_MANY_MEASURED_PIXEL</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>20</Value>
#       <Mean>NO_MEASURED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>21</Value>
#       <Mean>NOT_ENOUGH_MEASURED_STAR_FOR_MATCH</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>22</Value>
#       <Mean>NOT_ENOUGH_MEASURED_STAR_FOR_TRACK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>32</Value>
#       <Mean>ID_PROC_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>33</Value>
#       <Mean>NO_VALID_GRID_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>34</Value>
#       <Mean>TOO_FEW_MATCHED_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>35</Value>
#       <Mean>NO_MATCHED_PATTERN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>36</Value>
#       <Mean>NO_IDENTIFIED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>37</Value>
#       <Mean>NOT_ENOUGH_IDENTIFIED_STARS_FOR_AD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>38</Value>
#       <Mean>NOT_GUARANTEE_IDENTIFIED_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>39</Value>
#       <Mean>NO_VALID_NEXT_TRACKING_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>40</Value>
#       <Mean>NOT_ENOUGH_VALID_NEXT_TRACKING_STAR</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>41</Value>
#       <Mean>NO_VALID_ROI_DATA</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>48</Value>
#       <Mean>ATTITUDE_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>49</Value>
#       <Mean>ATTITUDE_ACQ_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>50</Value>
#       <Mean>ATTITUDE_TRK_OK</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>51</Value>
#       <Mean>ATTITUDE_NOT_ENOUGH_VECTOR_SET</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>52</Value>
#       <Mean>ATTITUDE_NOT_GUARANTEE</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS Attitude Number of Measured Stars</FieldName>
#     <NormalRange>0;20</NormalRange>
#     <Description>Number of measured stars</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS Attitude Number of Identified Stars</FieldName>
#     <NormalRange>0;20</NormalRange>
#     <Description>Number of identified stars</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS Attitude Number of Used Stars</FieldName>
#     <NormalRange>0;20</NormalRange>
#     <Description>Number of used stars for attitude</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit>nan</Unit>
#     <FieldName>STS Star Identification Method</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit>nan</Unit>
#     <FieldName>STS Sub OP Mode</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>STS OP Mode</FieldName>
#     <NormalRange />
#     <Description>Operation mode</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>Bootload Mode</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Standby Mode</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Imaging Mode</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>Attitude Mode</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>Simulated Image Mode</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>STS Fused Attitude Mode</FieldName>
#     <NormalRange />
#     <Description>STS Fused Attitude Mode</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean> Multi</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Single</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>STS Alternative Operation Flag</FieldName>
#     <NormalRange />
#     <Description>Normal operation or utilizing external attitude dataDisable(Normal Operation)Enable(Utilizing External Attitude Data)</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean> Disable</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Enable</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>STS Auto Calibration Flag</FieldName>
#     <NormalRange />
#     <Description>Optical auto calibration flag</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean> Disable</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Enable</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>STS Double Image Flag</FieldName>
#     <NormalRange />
#     <Description>Double image noise removal flag</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean> Disable</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Enable</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>0</Len>
#     <Unit />
#     <FieldName>STS Auto Tuning Flag</FieldName>
#     <NormalRange />
#     <Description>Auto tuning flag</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean> Disable</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Enable</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.INT16</Type>
#     <Len>2</Len>
#     <Unit>°C</Unit>
#     <FieldName>STS Attitude Detector Temperature</FieldName>
#     <NormalRange>-100;+100</NormalRange>
#     <Description>Detector Temperature (unit: ℃)- unit: ℃</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>STS Fused Attitude Status</FieldName>
#     <NormalRange />
#     <Description>STS Fused Attitude Status</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean> No valid STSs</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>STS1</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>STS2</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>8</Value>
#       <Mean>STS3</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>STS1+STS2</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>10</Value>
#       <Mean>STS1+STS3</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>12</Value>
#       <Mean>STS2+STS3</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>14</Value>
#       <Mean>STS1+STS2+STS3</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>MTR X Fire Direction</FieldName>
#     <NormalRange />
#     <Description>MTR X Fire Direction Command</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>No Fire</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Positive Fire</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Negative Fire </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>MTR Y Fire Direction</FieldName>
#     <NormalRange />
#     <Description>MTR Y Fire Direction Command</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>No Fire</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Positive Fire</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Negative Fire </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>MTR Z Fire Direction</FieldName>
#     <NormalRange />
#     <Description>MTR Z Fire Direction Command</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>No Fire</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>Positive Fire</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>Negative Fire </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>rpm</Unit>
#     <FieldName>RW1 Speed</FieldName>
#     <NormalRange>-2,000;2,000</NormalRange>
#     <Description>RW1 Speed</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>rpm</Unit>
#     <FieldName>RW2 Speed</FieldName>
#     <NormalRange>-2,000;2,000</NormalRange>
#     <Description>RW2 Speed</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>rpm</Unit>
#     <FieldName>RW3 Speed</FieldName>
#     <NormalRange>-2,000;2,000</NormalRange>
#     <Description>RW3 Speed</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>rpm</Unit>
#     <FieldName>RW4 Speed</FieldName>
#     <NormalRange>-2,000;2,000</NormalRange>
#     <Description>RW4 Speed</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.UINT32</Type>
#     <Len>4</Len>
#     <Unit>MB</Unit>
#     <FieldName>SSR Free Space</FieldName>
#     <NormalRange>0x00000000;0xFFFFFFFF</NormalRange>
#     <Description>Free space of SSR Filesystem. This value is updated in 1Hz event of PLT.</Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>PLT mode</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of PLT.</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>MODE_INIT </Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>MODE_SSR_FILE_LIST_INIT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>2</Value>
#       <Mean>MODE_FAIL_SSR_FILE_LIST_INIT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>3</Value>
#       <Mean>MODE_SCENARIO_NONE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>4</Value>
#       <Mean>MODE_IMG</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>5</Value>
#       <Mean>MODE_DWN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>6</Value>
#       <Mean>MODE_FILE_DELETE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>7</Value>
#       <Mean>MODE_FILE_SYSTEM_FORMAT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>10</Value>
#       <Mean>MODE_IMG_AND_DWN</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>PLT imaging state</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of PLT.</Description>
#     <ValueMean>
#       <Value>40</Value>
#       <Mean>IMG_ST_NONE </Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>41</Value>
#       <Mean>IMG_ST_SSR_INIT_AND_SEND_SCN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>42</Value>
#       <Mean>IMG_ST_SEND_SCN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>43</Value>
#       <Mean>IMG_ST_WAIT_SSR_SCN_SEND_FINISH</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>44</Value>
#       <Mean>IMG_ST_PL_INIT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>45</Value>
#       <Mean>IMG_ST_START</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>46</Value>
#       <Mean>IMG_ST_END</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>47</Value>
#       <Mean>IMG_ST_CANCEL</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>PLT download state</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of PLT.</Description>
#     <ValueMean>
#       <Value>60</Value>
#       <Mean>DWN_ST_NONE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>61</Value>
#       <Mean>DWN_ST_SSR_INIT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>62</Value>
#       <Mean>DWN_ST_SSR_NOT_INIT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>63</Value>
#       <Mean>DWN_ST_XTU_INIT_AND_SEND_SCN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>64</Value>
#       <Mean>DWN_ST_SCN_LOAD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>65</Value>
#       <Mean>DWN_ST_START</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>66</Value>
#       <Mean>DWN_ST_HOLD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>67</Value>
#       <Mean>DWN_ST_END</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>68</Value>
#       <Mean>DWN_ST_CANCEL</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>PLT file delete state</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of PLT.</Description>
#     <ValueMean>
#       <Value>100</Value>
#       <Mean>FDL_ST_NONE</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>101</Value>
#       <Mean>FDL_ST_SSR_INIT</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>102</Value>
#       <Mean>FDL_ST_WAIT_SSR_SCN_SEND_FINISH</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>103</Value>
#       <Mean>FDL_ST_SCN_LOAD</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>104</Value>
#       <Mean>FDL_ST_START</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>105</Value>
#       <Mean>FDL_ST_END</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>106</Value>
#       <Mean>FDL_ST_CANCEL</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>PLT file system format state</FieldName>
#     <NormalRange />
#     <Description>This value is updated in 1Hz event of PLT.</Description>
#     <ValueMean>
#       <Value>120</Value>
#       <Mean>FSF_ST_NONE </Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>121</Value>
#       <Mean>FSF_ST_SSR_ON</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>122</Value>
#       <Mean>FSF_ST_SSR_APP_RUN</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>123</Value>
#       <Mean>FSF_ST_SSR_SB_ON</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>124</Value>
#       <Mean>FSF_ST_START</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>125</Value>
#       <Mean>FSF_ST_END</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>126</Value>
#       <Mean>FSF_ST_CANCEL</Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit />
#     <FieldName>XAPM ID</FieldName>
#     <NormalRange />
#     <Description>ID of the currently active XAPM</Description>
#     <ValueMean>
#       <Value>0</Value>
#       <Mean>XAPM1</Mean>
#     </ValueMean>
#     <ValueMean>
#       <Value>1</Value>
#       <Mean>XAPM2 </Mean>
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Byte</Type>
#     <Len>1</Len>
#     <Unit>nan</Unit>
#     <FieldName>Reserved</FieldName>
#     <NormalRange>nan</NormalRange>
#     <Description>nan</Description>
#     <ValueMean>
#       <Value>nan</Value>
#       <Mean />
#     </ValueMean>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg</Unit>
#     <FieldName>XAPM Azimuth Angle</FieldName>
#     <NormalRange>-270;270</NormalRange>
#     <Description>Current azimuth angle of the active XAPM </Description>
#   </AlphanumericInfo>
#   <AlphanumericInfo>
#     <Value>0</Value>
#     <Type>System.Single</Type>
#     <Len>4</Len>
#     <Unit>deg</Unit>
#     <FieldName>XAPM Elevation Angle</FieldName>
#     <NormalRange>-110;110</NormalRange>
#     <Description>Current elevation angle of the active XAPM </Description>
#   </AlphanumericInfo>
# </FSWOperationInformation>

# %%
##저장
ElementTree(root_node).write("./FSWOperationInformation.xml")
